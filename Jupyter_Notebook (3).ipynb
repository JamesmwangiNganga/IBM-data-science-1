# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My names are James Mwangi Nganga

# %% [markdown]
# *I am interested in data science because it is a great career with a lot of opportunities and real life projects.
# Data science skills can be applied in most sectors such a agriculture, health , governance and security.

# %%
1+1
# Out:
# 2

# %% [markdown]
# * this is a bullet sentence
# - this is also a bullet sentence
#
# 1 numbered sentence
#  this ![audi.jpg](attachment:b85fc139-1fd2-4607-a744-d6465a23747c.jpg)
